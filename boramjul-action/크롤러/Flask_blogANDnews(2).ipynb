# %%
# flask 다운로드
# !pip install flask

# %%
import os
import sys
import urllib.request
import json
import pandas as pd
from flask import Flask, redirect, request
client_id = "3wU5xwXfFVL4LweQzLHQ"
client_secret = "K60NkftSAH"

# %%
##encText = urllib.parse.quote("칼의노래") ## 검색어
title = '불편한편의점'
author = '김호연'

data1 = urllib.parse.quote(title) ## 검색어
data2 = urllib.parse.quote(author) ## 검색어
#data1 = request.args['불편한 편의점']
#data2 = request.args['김호연']
booktitle_search = urllib.parse.quote(data1) ## 책 제목 검색어
author_search = urllib.parse.quote(data2) ## 책 저자 검색어

## <!-- 블로그 start -->
# url1 = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
url1 = "https://openapi.naver.com/v1/search/blog?query=" + data1 + "+" + data2 + "&display=3" # json 결과

## url1
request = urllib.request.Request(url1)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

blog_search = [] ## 블로그

if(rescode==200):
    response_body = response.read()
    #print(response_body.decode('utf-8')) ## 인코딩
    text = response_body.decode('utf-8') ## 인코딩
    dict = json.loads(text.strip()) ## text 변환
    blog_t = dict['items']
    for i in blog_t :
        blog_search.append(i['title'])
        blog_search.append(i['link'])
    print(blog_search)
else:
    print("Error Code:" + rescode)
## <!-- 블로그 end -->
# Out:
# ['<b>불편한 편의점</b> / <b>김호연</b> / 나무옆의자 - ebook', 'https://blog.naver.com/eunheeya2?Redirect=Log&logNo=222599644345', '《<b>불편한 편의점</b>》 <b>김호연</b>장편소설', 'https://blog.naver.com/lhjungtomato?Redirect=Log&logNo=222561321200', '[책읽기 029] <b>불편한 편의점</b>/<b>김호연</b>', 'https://blog.naver.com/bogri78?Redirect=Log&logNo=222594769682']

# %%
encText = urllib.parse.quote("칼의노래") ## 검색어

## <!-- 블로그 start -->
# url1 = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
url1 = "https://openapi.naver.com/v1/search/blog?query=" + encText + "&display=3" # json 결과

## url1
request = urllib.request.Request(url1)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

blog_search = [] ## 블로그

if(rescode==200):
    response_body = response.read()
    #print(response_body.decode('utf-8')) ## 인코딩
    text = response_body.decode('utf-8') ## 인코딩
    dict = json.loads(text.strip()) ## text 변환
    blog_t = dict['items']
    for i in blog_t :
        blog_search.append(i['title'])
        blog_search.append(i['link'])
    print(blog_search)
else:
    print("Error Code:" + rescode)
## <!-- 블로그 end -->

## <!-- 뉴스 start -->
url2 = "https://openapi.naver.com/v1/search/news?query=" + encText + "&display=3" # json 결과

## url2
request = urllib.request.Request(url2)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

news_search = []

if(rescode==200):
    response_body = response.read()
    #print(response_body.decode('utf-8'))
    text1 =response_body.decode('utf-8')
    dict = json.loads(text1.strip()) ## text 변환
    news_t = dict['items']
    for i in news_t :
        news_search.append(['title'])
        news_search.append(['link'])
    print(news_search)

else:
    print("Error Code:" + rescode)
## <!-- 뉴스 end -->

# %%
type(news_search)

# %% [markdown]
# ## flask 구조

# %%
from flask import Flask, redirect, request

app = Flask(__name__) # flask 서버객체 생성
 
# route(경로): 외부에서 접근할 때 페이지 구분을 위한 경로지정
@app.route('/', methods=['GET','POST'])
def index():
    ## web 클릭 데이터
#     data1 = request.args['title']
#     data2 = request.args['author']
#     data3 = request.args['cover']

    data1 = ''
    data2 = ''
    data3 = ''

    ## <!==== 크롤링 start ====>
    client_id = "3wU5xwXfFVL4LweQzLHQ"
    client_secret = "K60NkftSAH"
    ## <!!! 검색어 !!! >
    booktitle_search = urllib.parse.quote(data1) ## 책 제목 검색어
    author_search = urllib.parse.quote(date2) ## 책 저자 검색어
    ## <!-- 블로그 start -->
    url1 = "https://openapi.naver.com/v1/search/blog?query=" + data1 + "+" + date2 + "&display=3" # json 결과
    ## url1 == 블로그 search URL
    request = urllib.request.Request(url1)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    blog_search = [] ## 블로그 result 리스트
    if(rescode==200):
        response_body = response.read()
        #print(response_body.decode('utf-8')) ## 인코딩
        text = response_body.decode('utf-8') ## 인코딩
        dict = json.loads(text.strip()) ## text 변환
        blog_t = dict['items']
        for i in blog_t :
            blog_search.append(i['title'])
            blog_search.append(i['link'])
        print(blog_search)
    else:
        print("Error Code:" + rescode)
    ## <!-- 블로그 end -->
    ## <!-- 뉴스 start -->
    url2 = "https://openapi.naver.com/v1/search/news?query=" + encText + "&display=3" # json 결과
    ## url2 == 뉴스 search URL
    request = urllib.request.Request(url2)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    news_search = [] ## 뉴스 result 리스트
    if(rescode==200):
        response_body = response.read()
        #print(response_body.decode('utf-8'))
        text1 =response_body.decode('utf-8')
        dict = json.loads(text1.strip()) ## text 변환
        for i in news_t :
            news_search.append(i['title'])
            news_search.append(i['link'])
        print(news_search)
    else:
        print("Error Code:" + rescode)
    ## <!-- 뉴스 end -->
    url_title += 'title'
    url_author += 'author'
    url_cover += 'cover'
    bookinfo_url = 'http://172.30.1.51:8006/BoRamJul/bookinfo.jsp?title=' + url_title + "&author=" + url_author + "&cover=" + url_cover
    return render_template('bookinfo.jsp', blog=blog_search, news=news_search);
    #return redirect(bookinfo_url, blog=blog_search, news=news_search);
    #return redirect("http://127.0.0.1:8006/Map/info.jsp?URL1=test&URL2=test&URL3=test");
    ##return redirect("http://172.30.1.51:5020/BoRamㅇJul/bookinfo.jsp?"); ## [??]
    ## <!==== 크롤링 end ====>
    # main함수의 시작을 의미
    # 비유하자면 자바의 main(String[] args)메소드와 같은 역할

if __name__ == '__main__':
    # 웹서버주소(host)와 포트번호(port)를 지정하여 웹 서버 실행
    app.run(host='172.30.1.51', port=8006) ## [???] 주소 확인 필요

# %%
# !pip install flask_cors

# %%
from flask import Flask, redirect, request
from flask_cors import CORS, cross_origin
import json

app = Flask(__name__) # flask 서버객체 생성

CORS(app, resources={r'*': {'origins': '*'}})
# CORS(app, resources={r'*': {'origins': 'https://webisfree.com'}})
# CORS(app, resources={r'/_api/*': {'origins': 'https://webisfree.com:5000'}})


def crawling(title, author):
    result = ''
    ##encText = urllib.parse.quote("칼의노래") ## 검색어

    data1 = urllib.parse.quote(title) ## 검색어
    data2 = urllib.parse.quote(author) ## 검색어
    #data1 = request.args['불편한 편의점']
    #data2 = request.args['김호연']
    booktitle_search = urllib.parse.quote(data1) ## 책 제목 검색어
    author_search = urllib.parse.quote(data2) ## 책 저자 검색어

    ## <!-- 블로그 start -->
    # url1 = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
    url1 = "https://openapi.naver.com/v1/search/blog?query=" + data1 + "+" + data2 + "&display=3" # json 결과

    ## url1
    request = urllib.request.Request(url1)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    blog_search = [] ## 블로그

    if(rescode==200):
        response_body = response.read()
        #print(response_body.decode('utf-8')) ## 인코딩
        text = response_body.decode('utf-8') ## 인코딩
        dict = json.loads(text.strip()) ## text 변환
#         blog_t = dict['items']
#         for i in blog_t :
#             blog_search.append(i['title'])
#             blog_search.append(i['link'])

        blog_t = dict['items']
        for i in blog_t:
            blog_search.append({'title': i['title'], 'link': i['link']})
            
        result = blog_search
    else:
        result += "Error Code:"
        result += rescode
    ## <!-- 블로그 end -->
    return result

# route(경로): 외부에서 접근할 때 페이지 구분을 위한 경로지정
@app.route('/', methods=['GET','POST'])
def index():
    title = request.args['title']
    author = request.args['author']
#     cover = request.args['cover']
#     title = '불편한 편의점'
#     author = '김호연'
    print(crawling(title, author))
#     url = 'http://172.30.1.51:8006/BoRamJul/bookinfo.jsp?'
#     url += 'title='
#     url += title
#     url += '&author='
#     url += author
#     url += '&cover='
#     url += cover
#     url += '&test='
#     url += 'asdasd'   
    
    return json.dumps(crawling(title, author))
    
if __name__ == '__main__':
    # 웹서버주소(host)와 포트번호(port)를 지정하여 웹 서버 실행
    app.run(host='172.30.1.51', port=5021) ## [???] 주소 확인 필요
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://172.30.1.51:5021/ (Press CTRL+C to quit)

# %%
from flask import Flask, redirect, request
from flask_cors import CORS, cross_origin
import json

app = Flask(__name__) # flask 서버객체 생성

CORS(app, resources={r'*': {'origins': '*'}})
# CORS(app, resources={r'*': {'origins': 'https://webisfree.com'}})
# CORS(app, resources={r'/_api/*': {'origins': 'https://webisfree.com:5000'}})

def crawling(title, author):
    result = ''
    ##encText = urllib.parse.quote("칼의노래") ## 검색어

    data1 = urllib.parse.quote(title) ## 검색어
    data2 = urllib.parse.quote(author) ## 검색어
    #data1 = request.args['불편한 편의점']
    #data2 = request.args['김호연']
    booktitle_search = urllib.parse.quote(data1) ## 책 제목 검색어
    author_search = urllib.parse.quote(data2) ## 책 저자 검색어

    ## <!-- 블로그 start -->
    # url1 = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
    url1 = "https://openapi.naver.com/v1/search/blog?query=" + data1 + "+" + data2 + "&display=3" # json 결과

    ## url1
    request = urllib.request.Request(url1)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    blog_search = [] ## 블로그

    if(rescode==200):
        response_body = response.read()
        #print(response_body.decode('utf-8')) ## 인코딩
        text = response_body.decode('utf-8') ## 인코딩
#         dict = json.loads(text.strip()) ## text 변환
#         blog_t = dict['items']
#         for i in blog_t :
#             blog_search.append(i['title'])
#             blog_search.append(i['link'])
        result = json.loads(text.strip()) ## text 변환
    else:
        result += "Error Code:"
        result += rescode
    ## <!-- 블로그 end -->
    return result

# %%
blog_list = crawling('불편한 편의점(15만부 기념 윈터 에디션)', '김호연')

blog_info = [
    {'title': blog_list['items'][0]['title'], 'link': blog_list['items'][0]['link']},
    {'title': blog_list['items'][1]['title'], 'link': blog_list['items'][1]['link']},
    {'title': blog_list['items'][2]['title'], 'link': blog_list['items'][2]['link']},
]

json.dumps(blog_info)
# Out:
# '[{"title": "[<b>\\ubd88\\ud3b8\\ud55c \\ud3b8\\uc758\\uc810</b>]  ALWAYS", "link": "https://blog.naver.com/winmoon2?Redirect=Log&logNo=222604561229"}, {"title": "<b>\\ubd88\\ud3b8\\ud55c \\ud3b8\\uc758\\uc810</b> - <b>\\uae40\\ud638\\uc5f0</b> / \\ub098\\ubb34 \\uc606 \\uc758\\uc790", "link": "https://blog.naver.com/tapotis?Redirect=Log&logNo=222593946002"}, {"title": "<b>\\uae40\\ud638\\uc5f0</b>.", "link": "https://blog.naver.com/afx1979?Redirect=Log&logNo=222583650468"}]'

# %%
from flask import Flask, redirect, request, render_template

app = Flask(__name__) # flask 서버객체 생성

@app.route('/')
def index():
    return render_template('test.html', test='asdasd')


if __name__ == '__main__':
    # 웹서버주소(host)와 포트번호(port)를 지정하여 웹 서버 실행
    app.run(host='172.30.1.51', port=5021) ## [???] 주소 확인 필요
