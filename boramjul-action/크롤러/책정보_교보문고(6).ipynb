# %%
import requests as req  # requests 라이브러리 불러오기
from bs4 import BeautifulSoup as bs # BeautifulSoup 라이브러리 불러오기
import pandas as pd
from selenium import webdriver as wb   # 웹 통제
from selenium.webdriver.common.keys import Keys   # 웹에 값을 입력
import time ## time sleep
import re ## 정규식 표현 활용 ==> re 라이브러리

# %%
book_title = [] ## 책 제목
book_date = [] ## 책 출간일
book_author = [] ## 책 저자
book_brief = [] ## 책 요약
book_cat = [] ## 책 카테고리
book_publisher = [] ## 책 출판사
book_pages = [] ## 책 쪽수
book_content = [] ## 책 목차
book_cover = [] ## 책 표지이미지
book_hashtag = [] ## 책 해시태그

book_title1 = [] ## 책 제목1
book_title2 = [] ## 책 제목2
book_date1 = [] ## 책 출간일1
book_date2 = [] ## 책 출간일2
book_date3 = [] ## 책 출간일2
book_author1 = [] ## 책 저자1
book_author2 = [] ## 책 저자2
book_brief1 = [] ## 책 요약1
book_brief2 = [] ## 책 요약2
book_cat1 = [] ## 책 카테고리1
book_cat2 = [] ## 책 카테고리2
book_publisher1 = [] ## 책 출판사1
book_publisher2 = [] ## 책 출판사2
book_pages1 = [] ## 책 쪽수1
book_pages2 = [] ## 책 쪽수2
book_content1 = [] ## 책 목차1
book_content2 = [] ## 책 목차2
book_cover1 = [] ## 책 표지이미지1
book_cover2 = [] ## 책 표지이미지2
book_hashtag1 = [] ## 책 해시태그1
book_hashtag2 = [] ## 책 해시태그2

# %% [markdown]
# # test

# %%
driver = wb.Chrome() ## 드라이버
driver.get('http://www.kyobobook.co.kr/categoryRenewal/categoryMain.laf?perPage=20&mallGb=KOR&linkClass=01&menuCode=002') ## 교보문고 url

soup = bs(driver.page_source, 'lxml') ## 파싱

cnt = driver.find_elements_by_css_selector('#showcaseNew > div:nth-child(2) > div#eventPaging > div.list_paging > ul >li') ## 페이징 클릭 select

ck = driver.find_elements_by_css_selector('#prd_list_type1 > li > div > div.info_area > div.detail > div.title > a > strong') ## 제목 클릭 select

for i in range(len(cnt)): ## [!!!!!!!!!!!!!!!]이슈
    cnt = driver.find_elements_by_css_selector('#showcaseNew > div:nth-child(2) > div#eventPaging > div.list_paging > ul >li')
    cnt[i].click()
    time.sleep(1) # 셀레니움 쓰실 때 항상 time.sleep 여유
    # 이 반복문안에 클릭과 정보가져오는 반복문을 추가

    for j in range(len(ck)):
        ck = driver.find_elements_by_css_selector('#prd_list_type1 > li > div > div.info_area > div.detail > div.title > a > strong') ## 제목 클릭 select
        ck[j].click() ## 제목 select 클릭
        time.sleep(0) ## 웹페이지 바뀌는 시간
        soup = bs(driver.page_source, 'lxml') ## 파싱
        title = soup.select_one('h1.title > strong') ## 제목 css
        date = soup.select_one('div.author > span.date') ## 출간일 css
        author = soup.select_one('div.author > span.name > a') ## 저자 css
        brief = soup.select_one('h3+div+div.box_detail_article') ## 요약 css
        cat = soup.select_one('#container > div:nth-child(7) > div.content_left > div:nth-child(5) > ul > li > a') ## 카테고리 css
        publisher = soup.select_one('#container > div:nth-child(4) > form > div.box_detail_point > div.author > span:nth-child(3) > a') ## 출판사 css
        pages = soup.select_one('#container > div:nth-child(7) > div.content_left > div:nth-child(5) > table > tbody > tr:nth-child(2) > td') ## 쪽수 css
        #content = soup.select_one(             'div.box_detail_article') ## 목차 css
        cover = soup.select_one('#container > div:nth-child(4) > form > div.box_detail_info > div.box_detail_cover > div > a > img') ## 표지이미지 css
        cover_url = cover.get("src") ## 표지이미지 scr
        ## [??] 해시태그 사이 ','
        hashtag = soup.select_one('div.book_keyword > a') ## 해시태그 css 
        book_title1.append(title.text.strip()) ## 책 제목 append
        book_date1.append(date.text.strip()) ## 책 출간일 append
        book_author1.append(author.text.strip()) ## 책 저자
        book_brief1.append(brief.text.strip()) ## 책 요약
        book_cat1.append(cat.text.strip()) ## 책 카테고리
        book_publisher1.append(publisher.text.strip()) ## 책 출판사
        book_pages1.append(pages.text.strip()) ## 책 쪽수
        #book_content1.append(content1.text.strip()) ## 책 목차
        book_cover1.append(cover_url.strip()) ## 책 표지이미지
        book_hashtag1.append(hashtag.text.strip()) ## 책 해시태그
        print(book_title1)
        driver.back() # 뒤로가기
        time.sleep(2)
# Out:
# <ipython-input-36-10fae534fa13>:6: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   cnt = driver.find_elements_by_css_selector('#showcaseNew > div:nth-child(2) > div#eventPaging > div.list_paging > ul >li') ## 페이징 클릭 select
# <ipython-input-36-10fae534fa13>:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   ck = driver.find_elements_by_css_selector('#prd_list_type1 > li > div > div.info_area > div.detail > div.title > a > strong') ## 제목 클릭 select
# <ipython-input-36-10fae534fa13>:11: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   cnt = driver.find_elements_by_css_selector('#showcaseNew > div:nth-child(2) > div#eventPaging > div.list_paging > ul >li')
# <ipython-input-36-10fae534fa13>:17: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   ck = driver.find_elements_by_css_selector('#prd_list_type1 > li > div > div.info_area > div.detail > div.title > a > strong') ## 제목 클릭 select
# ['불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)']
# ['불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)']
# ['불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)']
# ['불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '우리가 빛의 속도로 갈 수 없다면']
# ['불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '우리가 빛의 속도로 갈 수 없다면', '방금 떠나온 세계']
# ['불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '우리가 빛의 속도로 갈 수 없다면', '방금 떠나온 세계', '듄. 1(DUNE)']
# ['불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '우리가 빛의 속도로 갈 수 없다면', '방금 떠나온 세계', '듄. 1(DUNE)', '파친코. 1']
# ['불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마', '불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '우리가 빛의 속도로 갈 수 없다면', '방금 떠나온 세계', '듄. 1(DUNE)', '파친코. 1', '소설 보다: 겨울 2021']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-10fae534fa13> in <module>
#      43         print(book_title1)
#      44         driver.back() # 뒤로가기
# ---> 45         time.sleep(2)
#      46
#
# KeyboardInterrupt:

# %%
cnt = driver.find_elements_by_css_selector('#showcaseNew > div:nth-child(2) > div#eventPaging > div.list_paging > ul >li') ## 페이징 클릭 select
cnt[1].click()
# Out:
# <ipython-input-34-2da325fbfe34>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   cnt = driver.find_elements_by_css_selector('#showcaseNew > div:nth-child(2) > div#eventPaging > div.list_paging > ul >li') ## 페이징 클릭 select
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-34-2da325fbfe34> in <module>
#       1 cnt = driver.find_elements_by_css_selector('#showcaseNew > div:nth-child(2) > div#eventPaging > div.list_paging > ul >li') ## 페이징 클릭 select
# ----> 2 cnt[1].click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      79     def click(self) -> None:
#      80         """Clicks the element."""
# ---> 81         self._execute(Command.CLICK_ELEMENT)
#      82
#      83     def submit(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     708             params = {}
#     709         params['id'] = self._id
# --> 710         return self._parent.execute(command, params)
#     711
#     712     def find_element(self, by=By.ID, value=None):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# ElementClickInterceptedException: Message: element click intercepted: Element <li>...</li> is not clickable at point (69, 6). Other element would receive the click: <a href="#">...</a>
#   (Session info: chrome=96.0.4664.110)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x00F16903+2517251]
# 	Ordinal0 [0x00EAF8E1+2095329]
# 	Ordinal0 [0x00DB2848+1058888]
# 	Ordinal0 [0x00DE3509+1258761]
# 	Ordinal0 [0x00DE1868+1251432]
# 	Ordinal0 [0x00DDF65D+1242717]
# 	Ordinal0 [0x00DDE4A8+1238184]
# 	Ordinal0 [0x00DD4037+1196087]
# 	Ordinal0 [0x00DF64D3+1336531]
# 	Ordinal0 [0x00DD3A36+1194550]
# 	Ordinal0 [0x00DF65BA+1336762]
# 	Ordinal0 [0x00E05BBF+1399743]
# 	Ordinal0 [0x00DF639B+1336219]
# 	Ordinal0 [0x00DD27A7+1189799]
# 	Ordinal0 [0x00DD3609+1193481]
# 	GetHandleVerifier [0x010A5904+1577972]
# 	GetHandleVerifier [0x01150B97+2279047]
# 	GetHandleVerifier [0x00FA6D09+534521]
# 	GetHandleVerifier [0x00FA5DB9+530601]
# 	Ordinal0 [0x00EB4FF9+2117625]
# 	Ordinal0 [0x00EB98A8+2136232]
# 	Ordinal0 [0x00EB99E2+2136546]
# 	Ordinal0 [0x00EC3541+2176321]
# 	BaseThreadInitThunk [0x762AFA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x778C7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x778C7A6E+238]

# %%
print(book_title1)
print(book_date1)
print(book_author1)
print(book_brief1)
print(book_cat1)
print(book_publisher1)
print(book_pages1)
print(book_content1)
print(book_cover1)
print(book_hashtag1)
# Out:
# ['불편한 편의점(15만부 기념 윈터 에디션)', '미드나잇 라이브러리(25만부 기념 퍼플 에디션)', '달러구트 꿈 백화점(100만부 기념 합본호: Gift Edition)', '달러구트 꿈 백화점. 2', '날마다 만우절', '옷소매 붉은 끝동 세트', '밝은 밤(별밤 에디션)', '달러구트 꿈 백화점', '크리스마스 피그', '눈으로 만든 사람', '완전한 행복', '허상의 어릿광대', '전지적 독자 시점 Part. 1(제4의 벽 북스탠드 에디션 세트)', '작별하지 않는다', '오늘 밤, 세계에서 이 사랑이 사라진다 해도(20만 부 기념 리커버 에디션)', '아몬드', '인간 실격', '지구 끝의 온실', '므레모사', '소마']
# ['2021년 04월 20일 출간', '2021년 04월 28일 출간', '2021년 12월 25일 출간', '2021년 07월 27일 출간', '2021년 07월 07일 출간', '2017년 04월 06일 출간', '2021년 07월 27일 출간', '2020년 07월 08일 출간', '2021년 10월 12일 출간', '2021년 06월 11일 출간', '2021년 06월 08일 출간', '2021년 12월 16일 출간', '2022년 01월 20일 출간', '2021년 09월 09일 출간', '2021년 06월 28일 출간', '2017년 03월 31일 출간', '2012년 04월 10일 출간\n\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t\n\t\t\t\t\t(1쇄 2004년 05월 15일)', '2021년 08월 18일 출간', '2021년 12월 25일 출간', '2021년 12월 24일 출간']
# ['김호연', '매트 헤이그', '이미예', '이미예', '윤성희', '강미강', '최은영', '이미예', 'J.K. 롤링', '최은미', '정유정', '히가시노 게이고', '싱숑', '한강', '이치조 미사키', '손원평', '다자이 오사무', '김초엽', '김초엽', '채사장']
# ['『불편한 편의점』 15만부 기념 한정판 윈터 에디션 출간!\n2021년 4월에 출간되어 15만이 넘는 독자의 뜨거운 사랑을 받고 있는 소설! 청파동 골목의 작은 편의점에서 펼쳐지는 마법 같은 이야기 『불편한 편의점』이 윈터 에디션을 선보입니다.\n눈 내리는 밤, 크리스마스 조명을 밝힌 편의점이 등대처럼 든든하게 골목을 지키고 있네요. 전면에 홀로그램 박을 입혀 신비롭게 반짝이는 표지가 특별함을 더합니다. 책 속에는 김호연 작가의 친필 서명도 인쇄되어 있답니다.\n서울역 노숙인 독고가 편의점에서 따뜻한 겨울을 보낸 것처럼 여러분의 겨울도 『불편한 편의점』과 함께 더욱 따스하길 바랍니다.\n\n 2013년 세계문학상 우수상 수상작 『망원동 브라더스』로 데뷔한 후 일상적 현실을 위트 있게 그린 경쾌한 작품과 인간의 내밀한 욕망을 기발한 상상력으로 풀어낸 스릴러 장르를 오가며 독자적인 작품 세계를 쌓아올린 작가 김호연. 그의 다섯 번째 장편소설 『불편한 편의점』이 나무옆의자에서 출간되었다. 『불편한 편의점』은 청파동 골목 모퉁이에 자리 잡은 작은 편의점을 무대로 힘겨운 시대를 살아가는 우리 이웃들의 삶의 속내와 희로애락을 따뜻하고 유머러스하게 담아낸 작품이다. 『망원동 브라더스』에서 망원동이라는 공간의 체험적 지리지를 잘 활용해 유쾌한 재미와 공감을 이끌어냈듯 이번에는 서울의 오래된 동네 청파동에 대한 공감각을 생생하게 포착해 또 하나의 흥미진진한 ‘동네 이야기’를 탄생시켰다. \n\n서울역에서 노숙인 생활을 하던 독고라는 남자가 어느 날 70대 여성의 지갑을 주워준 인연으로 그녀가 운영하는 편의점에서 야간 알바를 하면서 이야기가 시작된다. 덩치가 곰 같은 이 사내는 알코올성 치매로 과거를 기억하지 못하는 데다 말도 어눌하고 행동도 굼떠 과연 손님을 제대로 상대할 수 있을까 의구심을 갖게 하는데 웬걸, 의외로 그는 일을 꽤 잘해낼 뿐 아니라 주변 사람들을 묘하게 사로잡으면서 편의점의 밤을 지키는 든든한 일꾼이 되어간다. \n현실감 넘치는 캐릭터와 그들 간의 상호작용을 점입가경으로 형상화하는 데 일가견이 있는 작가의 작품답게 이 소설에서도 독특한 개성과 사연을 지닌 인물들이 차례로 등장해 서로 티격태격하며 별난 관계를 형성해간다. 고등학교에서 역사를 가르치다 정년퇴임하여 매사에 교사 본능이 발동하는 편의점 사장 염 여사를 필두로 20대 취준생 알바 시현, 50대 생계형 알바 오 여사, 매일 밤 야외 테이블에서 참참참(참깨라면, 참치김밥, 참이슬) 세트로 혼술을 하며 하루의 스트레스를 푸는 회사원 경만, 마지막이라는 각오로 청파동에 글을 쓰러 들어온 30대 희곡작가 인경, 호시탐탐 편의점을 팔아치울 기회를 엿보는 염 여사의 아들 민식, 민식의 의뢰를 받아 독고의 뒤를 캐는 사설탐정 곽이 그들이다. 제각기 녹록지 않은 인생의 무게와 현실적 문제를 안고 있는 이들은 각자의 시선으로 독고를 관찰하는데, 그 과정에서 발생하는 오해와 대립, 충돌과 반전, 이해와 공감은 자주 폭소를 자아내고 어느 순간 울컥 눈시울이 붉어지게 한다. 그렇게 골목길의 작은 편의점은 불편하기 짝이 없는 곳이었다가 고단한 삶을 위로하고 웃음을 나누는 특별한 공간이 된다.', '★ 아마존, 《뉴욕타임스》, 《선데이타임스》 장기 베스트셀러\n★ 〈어바웃 타임〉 제작사 영화화 예정!\n\n매트 헤이그의 소설 《미드나잇 라이브러리》가 출간 7개월 만에 25만 부 판매를 기록하며 베스트셀러에 오른 것을 기념해, 인플루엔셜에서 ‘퍼플 에디션’을 한정판으로 새롭게 선보인다. 죽기로 결심한 주인공 ‘노라 시드’가 삶과 죽음 사이에 존재하는 미스터리한 도서관 ‘미드나잇 라이브러리’에서 눈을 뜨며 시작되는 이 소설은 노라가 인생의 두 번째 기회를 얻으며, 가장 완벽한 삶을 찾기 위한 모험을 떠나는 이야기이다. \n\n“책을 덮는 순간 내일이 기대된다!” “내 인생의 반려책을 만났다” “다시 살아봐야겠다는 힘을 얻었다” 등 그녀의 여정을 함께했던 수많은 독자들이 자신의 감정과 경험을 블로그나 SNS에 공유하며 남긴 리뷰들도 소설만큼이나 우리에게 따뜻한 감동을 선사한다. 타인의 삶에 대한 공감, 자신의 삶에 대한 긍정, 살아있는 것 자체가 살아야 할 이유라는 깊은 성찰까지 매트 헤이그 작가가 보내는 공감과 위로의 메시지는 세대와 성별을 아우르며 전 세계 독자들의 마음을 사로잡았다. 영국 아마존 종합 베스트셀러 1위, 미국 아마존과 《뉴욕타임스》 50주 이상, 독일 《슈피겔》에서도 38주 연속 장기 베스트셀러에 올랐고, 덴마크, 이탈리아, 스페인, 루마니아, 타이완, 이란 등 세계 각지에서 출간되며 글로벌한 인기를 누리고 있다.', '한국형 판타지의 새로운 장르를 연 이미예 작가의 판타지 소설 《달러구트 꿈 백화점》이 1, 2권 통합 100만 부 판매를 기념해 특별 합본호로 출간됐다. 지난 2020년 7월, 1권 출간 이후 ‘힐링 판타지’라는 찬사를 받은 이 책은 2021년 7월, 2권 출간 직후부터 베스트셀러 1위를 차지하며 독자들의 사랑을 입증하였으며 출간 후 1년 4개월 만에 1, 2권 통합 100만 부를 판매하는 기록을 세웠다. 《달러구트 꿈 백화점》은 국내 소설 최초로 최단기 100만 부 판매를 달성하며 대한민국 출판시장에 새로운 한 획을 그었다고 할 수 있다. \n이번 합본호는 독자들에게 감사의 의미를 담아 1, 2권을 합쳐 양장 에디션으로 제작하였으며, 페니가 일하는 ‘달러구트의 꿈 백화점’을 비롯한 마을을 한눈에 볼 수 있는 일명 꿈 마을 지도도 특별 수록되어 있다. 특별 한정판으로 제작된 이 책은 연말연시 따뜻한 선물이 될 것이다.', '100만 독자를 사로잡은 《달러구트 꿈 백화점》, 그 두 번째 이야기\n\n\n어느덧 페니가 달러구트 꿈 백화점에서 일한 지도 1년이 넘었다.\n\n재고가 부족한 꿈을 관리하고, 꿈값 창고에서 감정으로 가득 찬 병을 옮기고, 프런트의 수많은 눈꺼풀 저울을 관리하는 일에 능숙해진 페니는 자신감이 넘친다. 게다가 꿈 산업 종사자로 인정을 받아야만 드나들 수 있는 ‘컴퍼니 구역’에도 가게 된 페니는 기쁜 마음을 감출 수 없다. \n\n하지만 그곳에서 페니를 기다리고 있는 건, 꿈에 대한 불만을 털어놓는 사람들로 가득한 ‘민원관리국’이었다. 설상가상 달러구트는 아주 심각한 민원 하나를 통째로 페니에게 맡기는데…\n\n“왜 저에게서 꿈까지 뺏어가려고 하시나요?”라는 알쏭달쏭한 민원을 남기고 발길을 끊어버린 792번 단골손님.\n\n페니는 과연 달러구트 꿈 백화점의 오랜 단골손님을 되찾을 수 있을까?', '완숙하고 예리한 시선을 바탕으로 인간과 삶에 대한 긍정으로 나아가는 이야기를 선보이는 작가 윤성희의 여섯번째 소설집 『날마다 만우절』이 출간되었다. 이십 년이 넘는 시간 동안 다섯 권의 소설집과 두 권의 장편소설 그리고 한 권의 중편소설을 출간하며 기복 없이 고른 작품활동을 이어온 그이지만, 2016년 봄부터 2020년 겨울까지 쓰인 열한 편의 단편이 묶인 이번 소설집은 그전과는 또다른 아우라를 내뿜으며 윤성희 소설세계의 새로운 챕터를 열어젖히고 있다는 점에서 그에게 ‘단편소설의 마에스트로’라는 수식을 붙이는 데 주저함이 없게 한다. \n\n\n특히 ‘훔친 킥보드를 타고 달리는 할머니’라는 인상적인 인물을 그려내어 “홀린 듯 읽으며 경험하는 이 놀라움은 윤성희를 읽는 이에게만 주어지는 선물이다”라는 평과 함께 2019 김승옥문학상 대상작으로 선정된 「어느 밤」을 포함해, 그간 한국문학에서 충분히 조명되지 않았던 ‘노년 여성’의 삶을 다각도로 묘사해내며 “윤성희의 소설과 견줄 수 있는 소설은 윤성희의 소설밖에 없다는 것을 새삼 느꼈다”(문학평론가 이지은), “이만큼이나 인간에 대한 애정을 넘겨받기 적당한 온도로 갈무리해 글로 옮겨내는 작가가 또 있을까”(문학평론가 김녕)라는 호평을 받은 작품들이 한데 모인 이번 소설집은 한여름에 맞이하는 크리스마스처럼 우리에게 뜻밖의 선물을 건네받는 듯한 기쁨을 안겨줄 것이다.', '강미강 장편소설『옷소매 붉은 끝동』. 왕은 궁녀를 사랑했다. 그러나 군왕의 삶은 삭막했고 사내에 앞서 임금이기를 선택했다. 필연적으로 베푼 만큼 앗아갔다. 주는 것보다 받는 것을 당연하게 여겼다. 세상은 여자들을 한 줄로 세워놓고 누가 ...
# ['소설', '소설', '소설', '소설', '소설', '소설', '소설', '소설', '소설', '소설', '소설', '소설', '소설', '소설', '소설', '소설', '소설', '소설', '소설', '소설']
# ['나무옆의자', '노진선', '팩토리나인', '팩토리나인', '문학동네', '청어람', '문학동네', '팩토리나인', '공보경', '문학동네', '은행나무', '김난주', '비채', '문학동네', '권영주', '창비', '김춘미', '자이언트북스', '현대문학', '웨일북(whalebooks)']
# ['268쪽', '408쪽', '552쪽', '308쪽', '316쪽', '928쪽', '344쪽', '300쪽', '336쪽', '392쪽', '524쪽', '552쪽', '350쪽', '332쪽', '376쪽', '263쪽', '192쪽', '392쪽', '204쪽', '384쪽']
# []
# ['http://image.kyobobook.co.kr/images/book/large/188/l9791161571188.jpg', 'http://image.kyobobook.co.kr/images/book/large/556/l9791191056556.jpg', 'http://image.kyobobook.co.kr/images/book/large/252/l9791165344252.jpg', 'http://image.kyobobook.co.kr/images/book/large/729/l9791165343729.jpg', 'http://image.kyobobook.co.kr/images/book/large/691/l9788954680691.jpg', 'http://image.kyobobook.co.kr/images/book/large/507/l9791104911507.jpg', 'http://image.kyobobook.co.kr/images/book/large/179/l9788954681179.jpg', 'http://image.kyobobook.co.kr/images/book/large/909/l9791165341909.jpg', 'http://image.kyobobook.co.kr/images/book/large/825/l9788983928825.jpg', 'http://image.kyobobook.co.kr/images/book/large/930/l9788954679930.jpg', 'http://image.kyobobook.co.kr/images/book/large/280/l9791167370280.jpg', 'http://image.kyobobook.co.kr/images/book/large/940/l9788990982940.jpg', 'http://image.kyobobook.co.kr/images/book/large/576/l9788934967576.jpg', 'http://image.kyobobook.co.kr/images/book/large/152/l9788954682152.jpg', 'http://image.kyobobook.co.kr/images/book/large/297/l9791191043297.jpg', 'http://image.kyobobook.co.kr/images/book/large/267/l9788936434267.jpg', 'http://image.kyobobook.co.kr/images/book/large/033/l9788937461033.jpg', 'http://image.kyobobook.co.kr/images/book/large/001/l9791191824001.jpg', 'http://image.kyobobook.co.kr/images/book/large/821/l9791167900821.jpg', 'http://image.kyobobook.co.kr/images/book/large/060/l9791192097060.jpg']
# ['한국소설', '인생', '한국소설', '한국소설', '한국소설', '한국로맨스소설', '한국소설', '한국소설', '어린이', '한국소설', '한국소설', '시리즈', '소설', '한국소설', '연애', '소설', '세계고전문학', '한국소설', '작가', '한국소설']

# %%
print(book_content1)

# %%
for i in book_date1: ## 책 출간일1
    temp_n = i.replace(" 출간", "") ## "출간" 제거
    book_date.append(temp_n) ## 책 출간일
    
for i in book_brief1: ## 책 요약1
    temp_n = i.replace("\n", "") ## "\n" 제거
    book_brief2.append(temp_n) ## 책 요약2
for i in book_brief2: ## 책 요약2
    temp_t = i.replace("\t", "") ## "\t" 제거
    book_brief.append(temp_t) ## 책 요약 추가
    
for i in book_pages1: ## 책 쪽수1
    temp_str = i.replace("쪽", "") ## "\n" 제거
    book_pages.append(temp_str) ## 책 쪽수

# for i in book_content1: ## 책 목차1
#     temp_n = i.replace("\n", "") ## "\n" 제거
#     book_content2.append(temp_n) ## 책 목차2
# for i in book_content2: ## 책 목차2
#     temp_t = i.replace("\t", "") ## "\t" 제거
#     book_content.append(temp_t) ## 책 목차
    
for i in book_hashtag1: # 책 해시태그1
    temp_n = i.replace("\n", ",") ## "\n" 제거
    book_hashtag.append(temp_n) ## 책 해시태그2

# %%
print(book_title1)
print(book_date)
print(book_author1)
print(book_brief)
print(book_cat1)
print(book_publisher1)
print(book_pages)
print(book_content)
print(book_cover)
print(book_hashtag1)

# %% [markdown]
# # 특정 문자열 삭제

# %%
# for i in book_title1: ## 책 제목1
#     temp_n = i.replace("\n", "") ## "\n" 제거
#     book_title2.append(temp_n) ## 책 제목1
# for i in book_title2: ## 책 제목2
#     temp_t = i.replace("\t", "") ## "\t" 제거
#     book_title.append(temp_t) ## 책 제목

# for i in book_date1: ## 책 출간일1
#     temp_n = i.replace(" 출간", "") ## "출간" 제거
#     book_date.append(temp_n) ## 책 출간일
    
# # for i in book_author1: ## 책 저자1
# #     temp_n = i.replace("\n", "") ## "\n" 제거
# #     book_author2.append(temp_n) ## 책 저자2
# # for i in book_author2: ## 책 저자2
# #     temp_t = i.replace("\t", "") ## "\t" 제거
# #     book_author.append(temp_t) ## 책 저자
    
# for i in book_brief1: ## 책 요약1
#     temp_n = i.replace("\n", "") ## "\n" 제거
#     book_brief2.append(temp_n) ## 책 요약2
# for i in book_brief2: ## 책 요약2
#     temp_t = i.replace("\t", "") ## "\t" 제거
#     book_brief.append(temp_t) ## 책 요약 추가
    
# # for i in book_cat1: ## 책 카테고리1
# #     temp_n = i.replace("\n", "") ## "\n" 제거
# #     book_cat2.append(temp_n) ## 책 카테고리2
# # for i in book_cat2: ## 책 카테고리2
# #     temp_t = i.replace("\t", "") ## "\t" 제거
# #     book_cat.append(temp_t) ## 책 카테고리 추가

# # for i in book_publisher1: ## 책 출판사1
# #     temp_n = i.replace("\n", "") ## "\n" 제거
# #     book_publisher2.append(temp_n) ## 책 출판사2
# # for i in book_publisher2: ## 책 출판사2
# #     temp_t = i.replace("\t", "") ## "\t" 제거
# #     book_publisher.append(temp_t) ## 책 출판사

# for i in book_pages1: ## 책 쪽수1
#     temp_str = i.replace("쪽", "") ## "\n" 제거
#     book_pages.append(temp_str) ## 책 쪽수

# for i in book_content1: ## 책 목차1
#     temp_n = i.replace("\n", "") ## "\n" 제거
#     book_content2.append(temp_n) ## 책 목차2
# for i in book_content2: ## 책 목차2
#     temp_t = i.replace("\t", "") ## "\t" 제거
#     book_content.append(temp_t) ## 책 목차
    
# for i in book_hashtag1: # 책 해시태그1
#     temp_n = i.replace("\n", ",") ## "\n" 제거
#     book_hashtag2.append(temp_n) ## 책 해시태그2

print(book_title)
print(book_date)
print(book_author)
print(book_brief)
print(book_cat)
print(book_publisher)
print(book_pages)
print(book_content)
print(book_cover)
print(book_hashtag1)

# %%
book_hashtag1

# %%
book_hashtag.replace('\n',"")

# %%
hashtag = book_hashtag[0].split('\n')
del hashtag[0]
del hashtag[len(hashtag)-1]
hashtag

# %%
print(book_date)
print(book_author)
print(book_brief)
print(book_cat)
print(book_publisher)
print(book_pages)
print(book_content)
print(book_cover)
print(book_hashtag)

# %% [markdown]
# # df

# %%
di1 = {'책 제목' : book_title,'책 출간일' : book_date, '책 저자' : book_author, '책 요약' : book_brief, '책 카테고리' : book_cat, '책 출판사' : book_publisher, '책 쪽수' : book_pages, '책 목차' : book_content, '책 표지이미지' : book_cover, '책 해시태그' : book_hashtag}
df = pd.DataFrame(di1)
df

# %%
df

# %% [markdown]
# # 리스트 초기화

# %%
book_title.clear() ## 책 제목
book_date.clear() ## 책 출간일
book_author.clear() ## 책 저자
book_brief.clear() ## 책 요약
book_cat.clear() ## 책 카테고리
book_publisher.clear() ## 책 출판사
book_pages.clear() ## 책 쪽수
book_content.clear() ## 책 목차
book_cover.clear() ## 책 표지이미지
book_hashtag.clear() ## 책 해시태그

# %%
print(book_title)
print(book_date)
print(book_author)
print(book_brief)
print(book_cat)
print(book_publisher)
print(book_pages)
print(book_content)
print(book_cover)
print(book_hashtag)

# %% [markdown]
# ### 페이지넘기기

# %%
driver2 = wb.Chrome()
driver2.get('http://www.kyobobook.co.kr/categoryRenewal/categoryMain.laf?perPage=20&mallGb=KOR&linkClass=01&menuCode=002')

# %%
cnt = driver2.find_elements_by_css_selector('#showcaseNew > div:nth-child(2) > div#eventPaging > div.list_paging > ul >li')

for i in range(len(cnt)):
    cnt = driver2.find_elements_by_css_selector('#showcaseNew > div:nth-child(2) > div#eventPaging > div.list_paging > ul >li')
    cnt[i].click()
    time.sleep(1)
    
    # 이 반복문안에 클릭과 정보가져오는 반복문을 추가
    for

# %%
len(cnt)

# %%
cnt[3].click()

# %% [markdown]
# ## 오류 확인

# %%
#soup.select_one('#container > div:nth-child(7) > div.content_left > div:nth-child(5) > div:nth-child(17), #container > div:nth-child(7) > div.content_left > div:nth-child(5) > div:nth-child(16)')

#soup.select_one('div.box_detail_content:nth-child(5)>h2:nth-child(16)+div')

#soup.select_one('#container > div:nth-child(7) > div.content_left > div:nth-child(5) > div:nth-child(16)')
#soup.select_one('h2.title_detail_basic:nth-child(15)+div')

soup.select_one('div.box_detail_article')

# %%
s=soup.select_one('div.box_detail_article')

# %%
s=soup.select('div.box_detail_article')
s[2]
